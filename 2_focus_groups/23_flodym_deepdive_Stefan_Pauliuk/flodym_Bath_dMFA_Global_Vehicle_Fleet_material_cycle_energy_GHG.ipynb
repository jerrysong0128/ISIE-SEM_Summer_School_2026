# %% [markdown]
# # dynamic material cycle modeling: Estimating the material content of the global vehicle fleet with a stock-driven model
# *ODYM example by Stefan Pauliuk, adapted for flodym, changed from inflow-driven to stock-driven model - prepared for the 2026 Bath summer school on dynamic MFA in Python*
#
# <img src="pictures/Bath_Cover.png" width="850" alt="2026 Bath dMFA summer school">
#
# This example shows a fully-fledged MFA system, designed to estimate the material composition of a multi-regional passenger vehicle fleet by 2060.
#
# The research questions asked are: How big is the energy consumption of the vehicle fleet and how large are the scope 1-2-3 GHG emissions?
#
# To answer these questions a dynamic material flow analysis of the global passenger vehicle fleet and the waste management industries is performed.
#
# The dynamic MFA model has the following indices:
#
# * t: time (1993-2060)
# * c: age-cohort (1993-2060) (internal only)
# * r: region (40 countries)
# * T: drive technology (gasoline and battery electric passenger vehicles)
# * p: process (vehicle markets, use phase, waste management industries, scrap markets)
# * m: engineering materials (25)
# * E: energy carrier (2)
# * X: env. extensions/pressure indicators (2: GWP 100 and metal ore footprint)
#
# The system definition of the model is given in the figure below. The time frame is 1993-2060. The figure also shows the aspects of the different system variables. The total registration of vehicles, for example, is broken down into individual materials, whereas the flow of deregistered vehicles is broken down into regions, age-cohorts, and materials.
#
# <img src="pictures/Vehicle_Fleet_MFA_scope_1_2_3.png" width="850" height="290" alt="MFA system">
#
# The model equations are as given in the lecture slide deck (Bath_dMFA_Python_SummerSchool_2026.pdf), software 5.
#
# The remaining system variables are calculated by mass balance.
#
# **Note:** Here, we'll add the energy consumption as flows to the flodym calculations, as well as the scope 1-2-3 GHG.

# %% [markdown]
# ## 1. Load flodym and other useful packages

# %%
from os.path import join

import numpy as np
import pandas as pd
import plotly.express as px

from flodym import (
    DimensionDefinition,
    Dimension,
    DimensionSet,
    ParameterDefinition,
    Parameter,
    FlowDefinition,
    StockDefinition,
    MFASystem,
    MFADefinition,
    DataReader,
    StockDrivenDSM,
)
from flodym.lifetime_models import NormalLifetime

# %% [markdown]
# ## 2. Define the data requirements, flows, stocks and MFA system equations
#
# We define the dimensions that are relevant for our system and the model parameters, processes, stocks and flows. We further define a class with our system equations in the compute method.

# %%
dimension_definitions = [
    DimensionDefinition(letter="t", name="time", dtype=int),
    DimensionDefinition(letter="r", name="region", dtype=str),
    DimensionDefinition(letter="m", name="material", dtype=str),
    DimensionDefinition(letter="T", name="drive technology", dtype=str),
    DimensionDefinition(letter="E", name="energy carrier", dtype=str), 
    DimensionDefinition(letter="X", name="extension", dtype=str),     
]

process_names = ["sysenv", "primary material production", "manufacturing", "use", "waste mgt", "energy supply", "atmosphere"]

parameter_definitions = [
    ParameterDefinition(name="vehicle lifetime by technology", dim_letters=("r", "T")),
    ParameterDefinition(name="vehicle material content by technology", dim_letters=("m", "T")),
    ParameterDefinition(name="vehicle historic future stock by technology", dim_letters=("t", "r", "T")),
    ParameterDefinition(name="EoL recovery rate", dim_letters=("m",)),
    ParameterDefinition(name="use phase energy", dim_letters=("t", "E", "T")),    # the annual MJ per vehicle. 
    # build this parameter from Bath_dMFA_2026_Software_Data.xlsx and add it to the data reader!
    ParameterDefinition(name="energy GHG scope 1", # !add dim_letters here!),   # GHG by energy carrier, applied to final energy consumption
    ParameterDefinition(name="energy GHG scope 2", # !add dim_letters here!),   # GHG by energy carrier, applied to final energy consumption
    ParameterDefinition(name="primary material GHG", # !add dim_letters here!),   # GHG by primary material produced
    ParameterDefinition(name="secondary material GHG", # !add dim_letters here!), # GHG by secondary material produced   
]

flow_definitions = [
    FlowDefinition(from_process_name="sysenv", to_process_name="primary material production", dim_letters=("t", "m")),
    FlowDefinition(from_process_name="primary material production", to_process_name="manufacturing", dim_letters=("t", "m")),    
    FlowDefinition(from_process_name="manufacturing", to_process_name="use", dim_letters=("t", "m")),
    FlowDefinition(from_process_name="use", to_process_name="waste mgt", dim_letters=("t", "m", "r", "T")),
    FlowDefinition(from_process_name="waste mgt", to_process_name="sysenv", dim_letters=("t", "m")),
    FlowDefinition(from_process_name="waste mgt", to_process_name="manufacturing", dim_letters=("t", "m")),
    # add the defintions of 2 energy flows: sysenv - energy supply and energy supply - use phase
    # add the definitions of 5 GHG flows from use phase (scope 1), energy supply (scope 2), primary material production (scope 3), 
    # secondary material production (scope 3) to atmosphere, and the balance from atmosphere to sysenv.     
]

stock_definitions = [
    StockDefinition(
        name="in use",
        process="use",
        dim_letters=("t", "r", "T"),
        subclass=StockDrivenDSM,
        lifetime_model_class=NormalLifetime,
        time_letter="t",
    )
]

mfa_definition = MFADefinition(
    dimensions=dimension_definitions,
    processes=process_names,
    flows=flow_definitions,
    stocks=stock_definitions,
    parameters=parameter_definitions,
)

# %%
class VehicleMFA(MFASystem):
    """We just need to define the compute method with our system equations,
    as all the other things we need are inherited from the MFASystem class."""

    def compute(self):
        self.compute_stock()
        self.compute_flows()

    def compute_stock(self):
        self.stocks["in use"].stock[...] = self.parameters["vehicle historic future stock by technology"]
        self.stocks["in use"].lifetime_model.set_prms(
            mean=self.parameters["vehicle lifetime by technology"],
            std=self.parameters["vehicle lifetime by technology"] * 0.3,
        )
        self.stocks["in use"].compute()

    def compute_flows(self):
        self.flows["manufacturing => use"][...] = self.stocks["in use"].inflow * self.parameters["vehicle material content by technology"] * 1e-9 # in Mt/yr
        self.flows["use => waste mgt"][...] = self.stocks["in use"].outflow * self.parameters["vehicle material content by technology"] * 1e-9 # in Mt/yr

        self.flows["waste mgt => manufacturing"][...] = (
            self.parameters["EoL recovery rate"] * self.flows["use => waste mgt"]
        )
 
        self.flows["waste mgt => sysenv"][...] = (
            self.flows["use => waste mgt"] - self.flows["waste mgt => manufacturing"]
        )
        self.flows["primary material production => manufacturing"][...] = (
            self.flows["manufacturing => use"] - self.flows["waste mgt => manufacturing"]
        )        
        self.flows["sysenv => primary material production"][...] = self.flows["primary material production => manufacturing"]
        # Add the energy consumption here: divide by 1e12 to get the result in EJ/yr

        # Add GHG flow calculations here: No unit conversion necessary, parameter units are set so that the result is Mt/yr (if energy comes in EJ/yr)

# %% [markdown]
# ## 3. Define our data reader
# Now that we have defined the MFA system and know what data we need, we can load the data.
# To do the data loading, we define a DataReader class. Such a class can be reused with different datasets of the same format by passing attributes, e.g. the directory where the data is stored, in the init function. In this example, we will also use this data reader in a following step.

# %%
class CustomDataReader(DataReader):
    """The methods `read_dimensions` and `read_parameters` are already defined in the parent
    DataReader class, and loop over the methods `read_dimension` and `read_parameter_values`
    that we specify for our usecase here.

    # This time, the data reader needs to be adjusted to include the use phase energy parameter and the energy carrier dimensions!
    """

    def __init__(self, data_directory, years):
        self.data_directory = data_directory
        self.years = years

    def read_dimension(self, dimension_definition: DimensionDefinition) -> Dimension:
        if (dim_name := dimension_definition.name) == "region":
            data = pd.read_excel(
                join(self.data_directory, "flodym_Bath_dMFA_Global_Vehicle_Fleet_vehicle_historic_future_stock_by_technology.xlsx"), "Data"
            )
            other_data = pd.read_excel(
                join(self.data_directory, "flodym_Bath_dMFA_Global_Vehicle_Fleet_vehicle_lifetime_by_technology.xlsx"), "Data"
            )
            data = (set(data[dim_name].unique())).intersection(set(other_data[dim_name].unique()))
            data = list(data)
            data.sort()
        elif dimension_definition.name == "drive technology":
            data = pd.read_excel(
                join(self.data_directory, "flodym_Bath_dMFA_Global_Vehicle_Fleet_vehicle_lifetime_by_technology.xlsx"), "Data"
            )
            data.columns = [x.lower() for x in data.columns]
            data = list(data["drive technology"].unique())
            data.sort()  
        elif dimension_definition.name == "material":
            data = pd.read_excel(
                join(self.data_directory, "flodym_Bath_dMFA_Global_Vehicle_Fleet_vehicle_material_content_by_technology.xlsx"), "Data"
            )
            data.columns = [x.lower() for x in data.columns]
            data = list(data["material"].unique())
            data.sort()     
        elif dimension_definition.name == "energy carrier":
            data = pd.read_excel(
                join(self.data_directory, "flodym_Bath_dMFA_Global_Vehicle_Fleet_use_phase_energy.xlsx"), "Data"
            )
            data.columns = [x.lower() for x in data.columns]
            data = list(data["energy carrier"].unique())
            data.sort()       
        elif dimension_definition.name == "extension":
            data = pd.read_excel(
                join(self.data_directory, "flodym_Bath_dMFA_Global_Vehicle_Fleet_energy_GHG_scope_1.xlsx"), "Data"
            )
            data.columns = [x.lower() for x in data.columns]
            data = list(data["extension"].unique())
            data.sort()  
        elif dimension_definition.name == "time":
            data = self.years
        return Dimension(
            name=dimension_definition.name,
            letter=dimension_definition.letter,
            dtype=dimension_definition.dtype,
            items=data,
        )

    def read_parameter_values(self, parameter_name: str, dims: DimensionSet) -> Parameter:
        data = pd.read_excel(
            join(self.data_directory, f"flodym_Bath_dMFA_Global_Vehicle_Fleet_{parameter_name.replace(' ', '_')}.xlsx"), "Data"
        )
        data = data.fillna(0)
        if "r" in dims:  # remove unwanted regions
            data = data[data["region"].isin(dims["r"].items)]

        if parameter_name == "vehicle lifetime by technology":
            data.columns = [x.lower() for x in data.columns]
            # remove unncessary columns
            data = data[[dim.name for dim in dims] + ["value"]]
        
        if parameter_name == "vehicle material content by technology":
            data.columns = [x.lower() for x in data.columns]
            # remove unncessary columns
            data = data[[dim.name for dim in dims] + ["value"]]

        if parameter_name == "EoL recovery rate":
            data.columns = [x.lower() for x in data.columns]
            # remove unncessary columns
            data = data[[dim.name for dim in dims] + ["value"]]  
        
        # add the formatting code for the energy consumption and four GHG parameters, following the EoL recovery rate example          
            
        return Parameter.from_df(dims=dims, df=data)

# %% [markdown]
# ## 4. Put everything together
# We make an instance of our `CustomDataReader`, read in the data and use it to create an instance of our `VehicleMFA` class. Then we can run the calculations and check the results

# %%
data_reader = CustomDataReader(data_directory="input_data", years=list(range(1993, 2061)))

vehicle_mfa = VehicleMFA.from_data_reader(
    definition=mfa_definition,
    data_reader=data_reader,
)
vehicle_mfa.compute()

# %% [markdown]
# ## 5. Post-process results and answer research questions
# ### 5.1. Plot energy consumption over time

# %%
energy_df = vehicle_mfa.flows["energy supply => use"].to_df(index=False) # results in list-shaped dataframe
energy_df_formatted = energy_df.set_index(['time','energy carrier','drive technology']).groupby(['time','energy carrier']).sum().squeeze().unstack('energy carrier')
fig = px.line(energy_df_formatted, title="final consumption of energy carriers, all regions combined, in EJ/yr")
fig.show(renderer="notebook")

# %% [markdown]
# ### 5.2. plot GHG

# %%
GHG_scope1_df                  = vehicle_mfa.flows["use => atmosphere"].to_df(index=False) # results in list-shaped dataframe
GHG_scope1_df_filter           = GHG_scope1_df[(GHG_scope1_df['extension'] == 'GHG GWP 100')].drop(columns=['extension'])
GHG_scope1_df_filter_formatted = GHG_scope1_df_filter.set_index(['time'])
fig = px.line(GHG_scope1_df_filter_formatted, title="Scope 1 GHG across regions, Mt CO2-eq/yr")
fig.show(renderer="notebook")

# %%
GHG_scope2_df                  = ... # modify code above for scope 2 GHG

# %%
GHG_scope3_df                  = ... # modify code above for scope 3 GHG
# produce separate code for primary and secondary material production GHG

# %%
GHG_scope3_df                  = ... # modify code above for scope 3 GHG
# produce separate code for primary and secondary material production GHG

# %%
GHG_scope_total_df                  = ... # modify code above for system-wide GHG
