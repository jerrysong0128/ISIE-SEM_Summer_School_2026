# %%
from pathlib import Path
import sys, os
workspace_path = os.path.abspath("..")
sys.path.insert(0, os.path.join(workspace_path, "notebook", "asset", "script"))
import Temoa_plot

# %% [markdown]
# The table below summarizes the three core scenario settings used in this analysis, highlighting differences in demand assumption and emissions constraint design.
#
# <div align="center">
#
# | **Scenario Name**                 | **Demand Level** | **Emissions Constraint** |
# |----------------------------------|------------------|--------------------------|
# | **BAU**                          | High             | No constraint            |
# | **Tech Abatement**               | High             | Constrained              |
# | **Tech Abatement + Circular Economy** | Low        | Constrained              |
#
# </div>

# %%
DB_PATH = f"{workspace_path}/data/2_temoa/22_mfa_utopia/221_BAU/mfa_utopia_cement.sqlite"
fig, axes, df_tech, df_co2, df_cap = Temoa_plot.plot_temoa_production_pathways(DB_PATH, scenario_name='BAU')

# %%
DB_PATH = f"{workspace_path}/data/2_temoa/22_mfa_utopia/222_TechAbatement/mfa_utopia_cement.sqlite"
fig, axes, df_tech, df_co2, df_cap = Temoa_plot.plot_temoa_production_pathways(DB_PATH, scenario_name='Tech Abatement')

# %%
DB_PATH = f"{workspace_path}/data/2_temoa/22_mfa_utopia/223_TechCE/mfa_utopia_cement.sqlite"
fig, axes, df_tech, df_co2, df_cap = Temoa_plot.plot_temoa_production_pathways(DB_PATH, scenario_name='Tech Abatement + Circular Economy')

# %% [markdown]
# ### Cost Comparison Across Scenarios
#
# The figure below compares total cement production cost and unit cement production cost across BAU, Tech Abatement, and Tech Abatement + Circular Economy scenarios.

# %%
scenario_sqlite_map = {
    'BAU': f"{workspace_path}/data/2_temoa/22_mfa_utopia/221_BAU/mfa_utopia_cement.sqlite",
    'Tech Abatement': f"{workspace_path}/data/2_temoa/22_mfa_utopia/222_TechAbatement/mfa_utopia_cement.sqlite",
    'Tech Abatement + Circular Economy': f"{workspace_path}/data/2_temoa/22_mfa_utopia/223_TechCE/mfa_utopia_cement.sqlite",
}

fig, axes, df_cost_cmp = Temoa_plot.plot_temoa_cement_cost_comparison(scenario_sqlite_map)
df_cost_cmp.head()
# Out:
#    period  total_cost_musd  cement_prod_mt scenario  unit_cost_musd_per_mt
# 0    2020     19560.295476            9.63      BAU            2031.183331
# 1    2030     21185.242140           10.43      BAU            2031.183331
# 2    2040     22911.747972           11.28      BAU            2031.183331
# 3    2050     24617.941969           12.12      BAU            2031.183331
# 4    2060     26527.254300           13.06      BAU            2031.183331

# %% [markdown]
# ### Scenario Result Diagrams
#
# <div align="center">
#
# #### BAU
# <img src="asset/pic/1_BAU_result_2060.svg" alt="BAU result 2060" width="900"/>
#
# #### Tech Abatement
# <img src="asset/pic/2_TechAbatement_result_2060.svg" alt="Tech Abatement result 2060" width="900"/>
#
# #### Tech Abatement + Circular Economy
# <img src="asset/pic/3_TechCE_result_2060.svg" alt="Tech Abatement + Circular Economy result 2060" width="900"/>
#
# </div>
